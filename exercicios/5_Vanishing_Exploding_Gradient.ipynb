# %% [markdown]
# <img src="https://raw.githubusercontent.com/alan-barzilay/NLPortugues/master/imagens/logo_nlportugues.png"   width="150" align="right">
#
#
# # Lista 5 - Vanishing & Exploding Gradient

# %% [markdown]
# ______________

# %% [markdown]
# Nessa lista exploraremos alguns problemas que podemos encontrar ao treinarmos uma rede recorrente. Esses problemas não são únicos das redes recorrentes, qualquer rede profunda pode sofrer de vanishing e exploding gradient, mas as redes recorrentes são especialmente instaveis devido a utilização da mesma matriz de pesos repetidas vezes.
#
# Começaremos explorando o exploding gradient e alguns de seus sintomas, em seguida utilizaremos gradient cliping para combate-lo.
# Por fim, estudaremos uma rede que sofre de vanishing gradient e tambem veremos uma estratégia para evitá-lo.

# %%
import tensorflow as tf
from tensorflow import keras
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_theme()

from sklearn.datasets import make_circles
from numpy import where
from sklearn.preprocessing import MinMaxScaler

from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import SGD
from tensorflow.keras.initializers import RandomUniform

# %% [markdown]
# # Exploding Gradient
#
# Para essa parte da lista nós preparamos uma rede simples, note como a *loss* cresce exponencialmente até virar infinita e logo em seguida NaN. Esse é um sintoma classico de exploding gradient. O gradiente está tão elevado que a cada etapa de backpropagation o passo de atualização dos parametros leva a um aumento na *loss* e isso segue crescendo até que exploda.

# %%
def f1(x):
    # função afim que pediremos para a rede aproximar
    return 5 + 10*x

xs = [x for x in range(100)]
ys = [f1(x) for x in range(100)]

# %%
opt = keras.optimizers.SGD()
model = tf.keras.Sequential([keras.layers.Dense(units=1, input_shape=[1])])
model.compile(optimizer=opt, loss="mean_squared_error")
model.fit(xs,ys,epochs=10)
# Out:
# Epoch 1/10
# 4/4 [==============================] - 1s 7ms/step - loss: 877678714421248.0000
# Epoch 2/10
# 4/4 [==============================] - 0s 8ms/step - loss: 319210591366553582692321984512.0000
# Epoch 3/10
# 4/4 [==============================] - 0s 5ms/step - loss: inf
# Epoch 4/10
# 4/4 [==============================] - 0s 8ms/step - loss: inf
# Epoch 5/10
# 4/4 [==============================] - 0s 10ms/step - loss: inf
# Epoch 6/10
# 4/4 [==============================] - 0s 4ms/step - loss: nan
# Epoch 7/10
# 4/4 [==============================] - 0s 5ms/step - loss: nan
# Epoch 8/10
# 4/4 [==============================] - 0s 4ms/step - loss: nan
# Epoch 9/10
# 4/4 [==============================] - 0s 4ms/step - loss: nan
# Epoch 10/10
# 4/4 [==============================] - 0s 4ms/step - loss: nan

# %% [markdown]
# ## Gradient Cliping
# ## <font color='blue'>Questão 1 </font>
#
#
# Exploraremos agora a técnica do *Gradient Cliping* para evitar o problema da explosão do gradiente. Exploraremos duas variações distintas dessa estratégia. A primeira é o `clipvalue`. Nessa abordagem impedimos que os valores das derivadas que compõe o vetor de gradiente saiam de um intervalo determinado. Pesquise na documentação do tensorflow por como adicionar a abordagem de clipvalue ao otimizador e refaça a rede anterior com essa mudança. Tente diferentes valores de intervalo até encontrar um que garanta o comportamento esperado do loss. Compile e treine seu novo modelo.

# %%
model = tf.keras.Sequential([keras.layers.Dense(units=1, input_shape=[1])])

# Seu código aqui
# Testei diferentes valores de clipvalue: 1.5, 1.2, 1.1, 1, 0.8
# Os teste que obtiveram um menor valor de loss, foram aqueles com clipvalue mais próximos de 1
# Mantive clipvalue=1.2 pois obtive o menor valor de loss no final das 400 épocas

my_opt = keras.optimizers.SGD(clipvalue=1.2) # em geral, loss < 0.3
model.compile(optimizer=my_opt, loss="mean_squared_error")

model.fit(xs,ys,epochs=400)
# Out:
# Epoch 1/400
# 4/4 [==============================] - 0s 4ms/step - loss: 378212.5938
# Epoch 2/400
400
# 4/4 [==============================] - 0s 4ms/step - loss: 2.2565
# Epoch 293/400
# 4/4 [==============================] - 0s 5ms/step - loss: 2.1411
# Epoch 294/400
# 4/4 [==============================] - 0s 4ms/step - loss: 2.1463
# Epoch 295/400
# 4/4 [==============================] - 0s 4ms/step - loss: 2.0382
# Epoch 296/400
# 4/4 [==============================] - 0s 4ms/step - loss: 1.9116
# Epoch 297/400
# 4/4 [==============================] - 0s 4ms/step - loss: 2.1010
# Epoch 298/400
# 4/4 [==============================] - 0s 5ms/step - loss: 1.8604
# Epoch 299/400
# 4/4 [==============================] - 0s 4ms/step - loss: 1.9037
# Epoch 300/400
# 4/4 [==============================] - 0s 4ms/step - loss: 1.9079
# Epoch 301/400
# 4/4 [==============================] - 0s 8ms/step - loss: 1.8197
# Epoch 302/400
# 4/4 [==============================] - 0s 4ms/step - loss: 1.9585
# Epoch 303/400
# 4/4 [==============================] - 0s 5ms/step - loss: 1.6796
# Epoch 304/400
# 4/4 [==============================] - 0s 4ms/step - loss: 1.7057
# Epoch 305/400
# 4/4 [==============================] - 0s 5ms/step - loss: 1.6640
# Epoch 306/400
# 4/4 [==============================] - 0s 8ms/step - loss: 1.6141
# Epoch 307/400
# 4/4 [==============================] - 0s 5ms/step - loss: 1.7070
# Epoch 308/400
# 4/4 [==============================] - 0s 4ms/step - loss: 1.6047
# Epoch 309/400
# 4/4 [==============================] - 0s 5ms/step - loss: 1.3832
# Epoch 310/400
# 4/4 [==============================] - 0s 4ms/step - loss: 1.3304
# Epoch 311/400
# 4/4 [==============================] - 0s 4ms/step - loss: 1.2413
# Epoch 312/400
# 4/4 [==============================] - 0s 4ms/step - loss: 1.3271
# Epoch 313/400
# 4/4 [==============================] - 0s 4ms/step - loss: 1.1503
# Epoch 314/400
# 4/4 [==============================] - 0s 4ms/step - loss: 1.1086
# Epoch 315/400
# 4/4 [==============================] - 0s 5ms/step - loss: 1.3764
# Epoch 316/400
# 4/4 [==============================] - 0s 6ms/step - loss: 1.0953
# Epoch 317/400
# 4/4 [==============================] - 0s 4ms/step - loss: 1.0572
# Epoch 318/400
# 4/4 [==============================] - 0s 5ms/step - loss: 1.0159
# Epoch 319/400
# 4/4 [==============================] - 0s 4ms/step - loss: 1.0353
# Epoch 320/400
# 4/4 [==============================] - 0s 6ms/step - loss: 1.0372
# Epoch 321/400
# 4/4 [==============================] - 0s 5ms/step - loss: 1.0001
# Epoch 322/400
# 4/4 [==============================] - 0s 5ms/step - loss: 0.9220
# Epoch 323/400
# 4/4 [==============================] - 0s 4ms/step - loss: 1.0405
# Epoch 324/400
# 4/4 [==============================] - 0s 4ms/step - loss: 0.9558
# Epoch 325/400
# 4/4 [==============================] - 0s 5ms/step - loss: 0.9436
# Epoch 326/400
# 4/4 [==============================] - 0s 5ms/step - loss: 0.8780
# Epoch 327/400
# 4/4 [==============================] - 0s 5ms/step - loss: 1.0086
# Epoch 328/400
# 4/4 [==============================] - 0s 5ms/step - loss: 1.0775
# Epoch 329/400
# 4/4 [==============================] - 0s 4ms/step - loss: 0.8873
# Epoch 330/400
# 4/4 [==============================] - 0s 5ms/step - loss: 0.8741
# Epoch 331/400
# 4/4 [==============================] - 0s 4ms/step - loss: 0.9509
# Epoch 332/400
# 4/4 [==============================] - 0s 4ms/step - loss: 0.9687
# Epoch 333/400
# 4/4 [==============================] - 0s 4ms/step - loss: 0.9240
# Epoch 334/400
# 4/4 [==============================] - 0s 4ms/step - loss: 0.9456
# Epoch 335/400
# 4/4 [==============================] - 0s 5ms/step - loss: 0.9012
# Epoch 336/400
# 4/4 [==============================] - 0s 4ms/step - loss: 0.9577
# Epoch 337/400
# 4/4 [==============================] - 0s 6ms/step - loss: 0.7542
# Epoch 338/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.6880
# Epoch 339/400
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6585
# Epoch 340/400
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6082
# Epoch 341/400
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6154
# Epoch 342/400
# 4/4 [==============================] - 0s 4ms/step - loss: 0.5638
# Epoch 343/400
# 4/4 [==============================] - 0s 4ms/step - loss: 0.5601
# Epoch 344/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.4960
# Epoch 345/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5036
# Epoch 346/400
# 4/4 [==============================] - 0s 4ms/step - loss: 0.4628
# Epoch 347/400
# 4/4 [==============================] - 0s 4ms/step - loss: 0.4545
# Epoch 348/400
# 4/4 [==============================] - 0s 4ms/step - loss: 0.4655
# Epoch 349/400
# 4/4 [==============================] - 0s 4ms/step - loss: 0.4188
# Epoch 350/400
# 4/4 [==============================] - 0s 4ms/step - loss: 0.4832
# Epoch 351/400
# 4/4 [==============================] - 0s 4ms/step - loss: 0.3779
# Epoch 352/400
# 4/4 [==============================] - 0s 4ms/step - loss: 0.4092
# Epoch 353/400
# 4/4 [==============================] - 0s 5ms/step - loss: 0.4357
# Epoch 354/400
# 4/4 [==============================] - 0s 4ms/step - loss: 0.4619
# Epoch 355/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.4041
# Epoch 356/400
# 4/4 [==============================] - 0s 4ms/step - loss: 0.3387
# Epoch 357/400
# 4/4 [==============================] - 0s 4ms/step - loss: 0.3081
# Epoch 358/400
# 4/4 [==============================] - 0s 4ms/step - loss: 0.4293
# Epoch 359/400
# 4/4 [==============================] - 0s 4ms/step - loss: 0.4006
# Epoch 360/400
# 4/4 [==============================] - 0s 4ms/step - loss: 0.3405
# Epoch 361/400
# 4/4 [==============================] - 0s 5ms/step - loss: 0.4656
# Epoch 362/400
# 4/4 [==============================] - 0s 4ms/step - loss: 0.3890
# Epoch 363/400
# 4/4 [==============================] - 0s 4ms/step - loss: 0.3984
# Epoch 364/400
# 4/4 [==============================] - 0s 4ms/step - loss: 0.3628
# Epoch 365/400
# 4/4 [==============================] - 0s 9ms/step - loss: 0.4173
# Epoch 366/400
# 4/4 [==============================] - 0s 5ms/step - loss: 0.3778
# Epoch 367/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.3912
# Epoch 368/400
# 4/4 [==============================] - 0s 4ms/step - loss: 0.4652
# Epoch 369/400
# 4/4 [==============================] - 0s 5ms/step - loss: 0.3574
# Epoch 370/400
# 4/4 [==============================] - 0s 5ms/step - loss: 0.4444
# Epoch 371/400
# 4/4 [==============================] - 0s 5ms/step - loss: 0.4325
# Epoch 372/400
# 4/4 [==============================] - 0s 5ms/step - loss: 0.4200
# Epoch 373/400
# 4/4 [==============================] - 0s 5ms/step - loss: 0.3949
# Epoch 374/400
# 4/4 [==============================] - 0s 5ms/step - loss: 0.3911
# Epoch 375/400
# 4/4 [==============================] - 0s 4ms/step - loss: 0.3928
# Epoch 376/400
# 4/4 [==============================] - 0s 5ms/step - loss: 0.3990
# Epoch 377/400
# 4/4 [==============================] - 0s 7ms/step - loss: 0.3449
# Epoch 378/400
# 4/4 [==============================] - 0s 4ms/step - loss: 0.4114
# Epoch 379/400
# 4/4 [==============================] - 0s 4ms/step - loss: 0.3955
# Epoch 380/400
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2985
# Epoch 381/400
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2868
# Epoch 382/400
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2843
# Epoch 383/400
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2526
# Epoch 384/400
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2563
# Epoch 385/400
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2425
# Epoch 386/400
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2389
# Epoch 387/400
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2178
# Epoch 388/400
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2283
# Epoch 389/400
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2355
# Epoch 390/400
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2118
# Epoch 391/400
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2184
# Epoch 392/400
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2102
# Epoch 393/400
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2290
# Epoch 394/400
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2184
# Epoch 395/400
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2167
# Epoch 396/400
# 4/4 [==============================] - 0s 7ms/step - loss: 0.2068
# Epoch 397/400
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2090
# Epoch 398/400
# 4/4 [==============================] - 0s 5ms/step - loss: 0.1962
# Epoch 399/400
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2008
# Epoch 400/400
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2050

# %% [markdown]
# ## <font color='blue'>Questão 2 </font>
#
# Agora exporaremos uma estratégia alternativa, o `clipnorm`. Nessa estratégia ao invés de limitarmos as componentes do vetor de gradiente, limitamos a sua norma a um intervalo pré-determinado.
#
# De maneira análoga à questão anterior, pesquise na documentação por como aplicar essa estratégia ao otimizador e refaça a rede anterior, compilando-a e treinando-a para evitar o problema da explosão do gradiente.

# %%
model = tf.keras.Sequential([keras.layers.Dense(units=1, input_shape=[1])])

400
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2753
# Epoch 399/400
# 4/4 [==============================] - 0s 5ms/step - loss: 0.3107
# Epoch 400/400
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2959

# %% [markdown]
# ________________________
#
#
#
# # Vanishing
#
# Lidar com Vanishing Gradient é muito mais desafiador do que com exploding gradient. Não é trivial determinar se o baixo desempenho de sua rede é causado por vanishing gradient, uma vez que seus sintomas são relativamente genéricos e ele pode ser apenas mais um dos fatores que prejudicam seu desempenho. Além disso não existe uma solução geral e definitiva, como o gradient cliping em casos de explosão do gradiente.
#
# Preparamos algumas redes para poder explorar um caso mais simples de vanishing gradient e também uma possivel solução. Começamos gerando um dataset simples de classificação e treinamos uma rede rasa que obtem uma boa performance.
# Ao aprofundarmos essa rede podemos notar que sua performance cai drasticamente se tornando quase tão eficiente quanto jogar uma moeda para chutar a classe do ponto, ela nem mesmo é capaz de "*overfittar*" os dados. Utilizaremos uma nova forma de inicialização dos pesos da rede para tentar recuperar nossa performance e novamente.

# %% [markdown]
# ## Definindo nossos dados
# Primeiro definiremos um toy dataset bem simples que utilizaremos para nossos modelos e uma função auxiliar para facilitar a comparação de nossos modelos.
#
#
# Esses dados e redes foram inspirados e adaptados [deste post](https://machinelearningmastery.com/how-to-fix-vanishing-gradients-using-the-rectified-linear-activation-function/).

# %%
# gera dataset de classificação
X, y = make_circles(n_samples=1000, noise=0.1, random_state=1)

# escala input para [-1,1]
scaler = MinMaxScaler(feature_range=(-1, 1))
X = scaler.fit_transform(X)

# plota visualização do dataset
for i in range(2):
    samples_ix = where(y == i)
    plt.scatter(X[samples_ix, 0], X[samples_ix, 1], label=str(i))
plt.legend()
plt.show()

# separa em teste e treino
n_train = 500
trainX, testX = X[:n_train, :], X[n_train:, :]
trainy, testy = y[:n_train], y[n_train:]

# %%
def run_model(model,log_to_tb= False ,trainX=trainX,trainy=trainy,testX=testX,testy=testy):
    """
    Função auxiliar que recebe um modelo e realiza seu treinamento e avaliação no dataset.
    """
    model.summary()

    # compila modelo
    opt = keras.optimizers.SGD(learning_rate=0.01, momentum=0.9)
    model.compile(loss='binary_crossentropy', optimizer=opt, metrics=['accuracy'])


    # fit modelo
    history = model.fit(trainX, trainy, validation_data=(testX, testy), epochs=500, verbose=0)

    # avalia modelo
    _, train_acc = model.evaluate(trainX, trainy, verbose=0)
    _, test_acc = model.evaluate(testX, testy, verbose=0)
    print("\n")
    print('Train: %.3f, Test: %.3f' % (train_acc, test_acc))


    # plota acurácia/training history
    plt.ylim(0, 1)
    plt.title("Acurácia "+ model.name)
    plt.plot(history.history['accuracy'], label='train')
    plt.plot(history.history['val_accuracy'], label='test')
    plt.legend()
    plt.show()

# %% [markdown]
# ## Rede rasa
# Aqui temos uma rede rasa com apenas uma camada oculta e uma de output, note que ela é capaz de atingir uma performance razoavel após 300 epochs.
#
# Nós estamos utilizando um inicializador diferente do padrão para os pesos da camada, que sorteia os pesos iniciais a partir de uma distribuição uniforme no intervalo [0,1].

# %%
#define modelo raso
init = RandomUniform(minval=0, maxval=1)

model = keras.Sequential(name="modelo_raso")
model.add(keras.layers.Dense(5,
                       input_dim=2,
                       activation="tanh",
                       kernel_initializer=init,
                       name="raso_1"))
model.add(keras.layers.Dense(1,
                       activation='sigmoid',
                       kernel_initializer=init,
                       name="raso_output"))


run_model(model)
# Out:
# Model: "modelo_raso"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  raso_1 (Dense)              (None, 5)                 15
#
#  raso_output (Dense)         (None, 1)                 6
#
# =================================================================
# Total params: 21 (84.00 Byte)
# Trainable params: 21 (84.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# /usr/local/lib/python3.10/dist-packages/keras/src/initializers/initializers.py:120: UserWarning: The initializer RandomUniform is unseeded and being called multiple times, which will return identical values each time (even if the initializer is unseeded). Please update your code to provide a seed to the initializer, or avoid using the same initializer instance more than once.
#   warnings.warn(
# Train: 0.790, Test: 0.794

# %% [markdown]
# ## Rede funda
#
# Agora tornaremos nossa rede mais funda com 5 camadas ocultas e uma de output, note como a performance cai drasticamente e se torna próxima a um chute aleatório. Embora o modelo seja mais complexo e poderoso nós não conseguimos treina-lo.

# %%
# define modelo mais fundo
init = RandomUniform(minval=0, maxval=1)

model = Sequential(name="modelo_fundo")
model.add(Dense(5, input_dim=2, activation='tanh', kernel_initializer=init,name="funda_1"))
model.add(Dense(5, activation='tanh', kernel_initializer=init,name="funda_2"))
model.add(Dense(5, activation='tanh', kernel_initializer=init,name="funda_3"))
model.add(Dense(5, activation='tanh', kernel_initializer=init,name="funda_4"))
model.add(Dense(5, activation='tanh', kernel_initializer=init,name="funda_5"))
model.add(Dense(1, activation='sigmoid', kernel_initializer=init,name="funda_output"))


run_model(model,log_to_tb=True)
# Out:
# Model: "modelo_fundo"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  funda_1 (Dense)             (None, 5)                 15
#
#  funda_2 (Dense)             (None, 5)                 30
#
#  funda_3 (Dense)             (None, 5)                 30
#
#  funda_4 (Dense)             (None, 5)                 30
#
#  funda_5 (Dense)             (None, 5)                 30
#
#  funda_output (Dense)        (None, 1)                 6
#
# =================================================================
# Total params: 141 (564.00 Byte)
# Trainable params: 141 (564.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
#
#
# Train: 0.592, Test: 0.552

# %% [markdown]
# ### Utilizando inicialização de Xavier Glorot
#
# Agora utilizaremos uma técnica de combate ao vanishing gradient, utilizaremos outro inicializador para os pesos da rede. O [inicializador de Xavier Glorot](http://proceedings.mlr.press/v9/glorot10a/glorot10a.pdf) é o inicializador default de algumas camadas do keras como a camada densa que utilizamos.
#
# ## <font color='blue'>Questão 3 </font>
# Repita, na célula seguinte a rede da célula anterior, mas trocando o seu incializador pelo de Xavier Glorot uniforme, de maneira explícita. Treine o novo modelo usando a função `run model`. Faça uma análise comparativa (com o mesmo tamanho de um tweet) das curvas de obtidas para esta rede e para a rede anterior.

# %%
# Seu código aqui
init = tf.keras.initializers.GlorotUniform()

model = Sequential(name="modelo_fundo")
model.add(Dense(5, input_dim=2, activation='tanh', kernel_initializer=init,name="funda_1"))
model.add(Dense(5, activation='tanh', kernel_initializer=init,name="funda_2"))
model.add(Dense(5, activation='tanh', kernel_initializer=init,name="funda_3"))
model.add(Dense(5, activation='tanh', kernel_initializer=init,name="funda_4"))
model.add(Dense(5, activation='tanh', kernel_initializer=init,name="funda_5"))
model.add(Dense(1, activation='sigmoid', kernel_initializer=init,name="funda_output"))


run_model(model,log_to_tb=True)
# Out:
# Model: "modelo_fundo"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  funda_1 (Dense)             (None, 5)                 15
#
#  funda_2 (Dense)             (None, 5)                 30
#
#  funda_3 (Dense)             (None, 5)                 30
#
#  funda_4 (Dense)             (None, 5)                 30
#
#  funda_5 (Dense)             (None, 5)                 30
#
#  funda_output (Dense)        (None, 1)                 6
#
# =================================================================
# Total params: 141 (564.00 Byte)
# Trainable params: 141 (564.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# /usr/local/lib/python3.10/dist-packages/keras/src/initializers/initializers.py:120: UserWarning: The initializer GlorotUniform is unseeded and being called multiple times, which will return identical values each time (even if the initializer is unseeded). Please update your code to provide a seed to the initializer, or avoid using the same initializer instance more than once.
#   warnings.warn(
# Train: 0.844, Test: 0.854

# %% [markdown]
# ## <font color='red'> Sua análise aqui </font>
#
# No primeiro modelo, utilizando a inicialização `RandomUniform` é possível perceber que devido ao Vanishing Gradient a acurácia permaneceu praticamente inalterada, mesmo depois de 500 épocas. Isso ocorre porque o gradiente é muito pequeno e assim, o modelo não consegue se ajustar aos dados. Já no segundo modelo, usando o initializador `GlorotUniform` nota-se que antes das 100 primeiras épocas o modelo conseguiu se ajustar aos dados e obter uma acurácia razoável, em torno de 0.8, indicando que, provavelmente, o problema do Vanishing Gradient foi resolvido.
